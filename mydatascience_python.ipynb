# %% [markdown]
# <a href="https://colab.research.google.com/github/SnegaSen/my_first.colab/blob/main/mydatascience_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-8e08ba88-fd6b-464d-8598-54a5a04674a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e08ba88-fd6b-464d-8598-54a5a04674a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Stars1.csv to Stars1.csv

# %%
import io
df = pd.read_csv(io.BytesIO(upload['Stars1.csv']))
df
# Out:
#      Temperature              L          R    A_M  Color Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12    Red              M     0
# 1           3042       0.000500     0.1542  16.60    Red              M     0
# 2           2600       0.000300     0.1020  18.70    Red              M     0
# 3           2800       0.000200     0.1600  16.65    Red              M     0
# 4           1939       0.000138     0.1030  20.06    Red              M     0
# ..           ...            ...        ...    ...    ...            ...   ...
# 235        38940  374830.000000  1356.0000  -9.93   Blue              O     5
# 236        30839  834042.000000  1194.0000 -10.63   Blue              O     5
# 237         8829  537493.000000  1423.0000 -10.73  White              A     5
# 238         9235  404940.000000  1112.0000 -11.23  White              A     5
# 239        37882  294903.000000  1783.0000  -7.80   Blue              O     5
#
# [240 rows x 7 columns]

# %%
df.describe()
# Out:
#         Temperature              L            R         A_M        Type
# count    240.000000     240.000000   240.000000  240.000000  240.000000
# mean   10497.462500  107188.361635   237.157781    4.382396    2.500000
# std     9552.425037  179432.244940   517.155763   10.532512    1.711394
# min     1939.000000       0.000080     0.008400  -11.920000    0.000000
# 25%     3344.250000       0.000865     0.102750   -6.232500    1.000000
# 50%     5776.000000       0.070500     0.762500    8.313000    2.500000
# 75%    15055.500000  198050.000000    42.750000   13.697500    4.000000
# max    40000.000000  849420.000000  1948.500000   20.060000    5.000000

# %%
df.columns
# Out:
# Index(['Temperature', 'L', 'R', 'A_M', 'Color', 'Spectral_Class', 'Type'], dtype='object')

# %%
print(df.size)
print(df.shape)
# Out:
# 1680
# (240, 7)

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      Temperature              L          R    A_M  Color Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12    Red              M     0
# 1           3042       0.000500     0.1542  16.60    Red              M     0
# 2           2600       0.000300     0.1020  18.70    Red              M     0
# 3           2800       0.000200     0.1600  16.65    Red              M     0
# 4           1939       0.000138     0.1030  20.06    Red              M     0
# ..           ...            ...        ...    ...    ...            ...   ...
# 235        38940  374830.000000  1356.0000  -9.93   Blue              O     5
# 236        30839  834042.000000  1194.0000 -10.63   Blue              O     5
# 237         8829  537493.000000  1423.0000 -10.73  White              A     5
# 238         9235  404940.000000  1112.0000 -11.23  White              A     5
# ...

# %%
df.isnull().sum()
# Out:
# Temperature       0
# L                 0
# R                 0
# A_M               0
# Color             0
# Spectral_Class    0
# Type              0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Temperature       0
# L                 0
# R                 0
# A_M               0
# Color             0
# Spectral_Class    0
# Type              0
# dtype: int64

# %%
print(df.head(2))
# Out:
#    Temperature       L       R    A_M Color Spectral_Class  Type
# 0         3068  0.0024  0.1700  16.12   Red              M     0
# 1         3042  0.0005  0.1542  16.60   Red              M     0

# %%
print(df.tail(3))
# Out:
#      Temperature         L       R    A_M  Color Spectral_Class  Type
# 237         8829  537493.0  1423.0 -10.73  White              A     5
# 238         9235  404940.0  1112.0 -11.23  White              A     5
# 239        37882  294903.0  1783.0  -7.80   Blue              O     5

# %%
x=df["L"].mean()
df["L"].fillna(x,inplace=True)
print(x)
# Out:
# 107188.36163460833

# %%
y=df["L"].median()
df["L"].fillna(x,inplace=True)
print(y)
# Out:
# 0.07050000000000001

# %%
z=df["L"].mode()[0]
df["L"].fillna(x,inplace=True)
print(z)
# Out:
# 200000.0

# %%
data={'Temperatue','L'}
df.plot(x='Temperature',y='L')

# %%
df.plot(x='Temperature',y='L',kind='scatter')

# %%
df.plot(x='Temperature',y='L',kind='bar')

# %%
data={'Type':[0,1,2,3,4,5]}
df=pd.DataFrame(data,columns=['Type'],index=['Type0','Type1','Type2','Type3','Type4','Type5'])
df.plot.pie(y='Type',figsize=(5,5),autopct='%1.1f%%',startangle=90)
plt.show()

# %%
data={'Type':[0,1,2,3,4,5]}
df=pd.DataFrame(data,columns=['Type'],index=['Type0','Type1','Type2','Type3','Type4','Type5'])
df.plot.pie(y='Type',figsize=(10,10),autopct='%1.1f%%',startangle=90)
plt.title('STAR TYPES')
plt.axis('equal')
plt.show()
